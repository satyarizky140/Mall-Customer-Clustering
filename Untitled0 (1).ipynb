# %% [markdown]
# #IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import seaborn as sns

# %% [markdown]
# #Import the dataset and save it as a dataframe

# %%
data = pd.read_csv('Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# #Use 2 columns as the basic features for our clustering

# %%
data_clus = data.iloc[:, 3:5]
data_clus.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %% [markdown]
# #Plot the initial data of all 200 customers

# %%
plt.scatter(data_clus.iloc[:,0], data_clus.iloc[:,1],c='black')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %%
clus_array = np.array(data_clus)
print (clus_array)
# Out:
# [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
# ...

# %% [markdown]
# #For preprocessing, we will use the MinMaxScaler

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(clus_array)
data_scaled
# Out:
# array([[0.        , 0.3877551 ],
#        [0.        , 0.81632653],
#        [0.00819672, 0.05102041],
#        [0.00819672, 0.7755102 ],
#        [0.01639344, 0.39795918],
#        [0.01639344, 0.76530612],
#        [0.02459016, 0.05102041],
#        [0.02459016, 0.94897959],
#        [0.03278689, 0.02040816],
#        [0.03278689, 0.7244898 ],
#        [0.03278689, 0.13265306],
#        [0.03278689, 1.        ],
#        [0.04098361, 0.14285714],
#        [0.04098361, 0.7755102 ],
#        [0.04098361, 0.12244898],
#        [0.04098361, 0.79591837],
#        [0.04918033, 0.34693878],
#        [0.04918033, 0.66326531],
#        [0.06557377, 0.28571429],
#        [0.06557377, 0.98979592],
#        [0.07377049, 0.34693878],
#        [0.07377049, 0.73469388],
#        [0.08196721, 0.04081633],
#        [0.08196721, 0.73469388],
#        [0.10655738, 0.13265306],
#        [0.10655738, 0.82653061],
#        [0.10655738, 0.31632653],
#        [0.10655738, 0.6122449 ],
# ...

# %% [markdown]
# #Set the range to predict the value of k in the range of 1 to 10.

# %%
distortions = []
K = range(1,10)
for k in K:
  kmeanModel = KMeans(n_clusters = k)
  kmeanModel.fit(data_scaled)
  distortions.append(kmeanModel.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# #See the distortion in the visualization

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')

# %% [markdown]
# #Create a model using our scaled data

# %%
kmeanModel = KMeans(n_clusters=5)
kmeanModel.fit(data_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
print(kmeanModel.cluster_centers_)
# Out:
# [[0.08792846 0.79962894]
#  [0.32866853 0.49340468]
#  [0.6        0.16443149]
#  [0.58638083 0.82783883]
#  [0.08792846 0.19619666]]

# %% [markdown]
# #Visualize the position of the centroids

# %%
plt.scatter(data_scaled[:,0], data_scaled[:,1], s=50, c='black', marker='o', alpha=1)
centers = kmeanModel.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=1, marker='o')
plt.title('K-Means Centroid')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %% [markdown]
# #Predict our scaled data using the K-Means Model

# %%
y_kmeans = kmeanModel.predict(data_scaled)

plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeanModel.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %% [markdown]
# #Create a new dataframe of the cluster results.

# %%
result = pd.DataFrame(data = y_kmeans)
result.columns=['cluster']
result.head()
# Out:
#    cluster
# 0        4
# 1        0
# 2        4
# 3        0
# 4        4

# %% [markdown]
# #Combine the results with the initial dataset

# %%
output = pd.concat([data, result], axis=1)
output.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    cluster
# 0        4
# 1        0
# 2        4
# 3        0
# 4        4

# %% [markdown]
# #re-plot the grouping results by adding legend information using the seaborn library

# %%
sns.scatterplot(x=output.iloc[:,3], y=output.iloc[:,4], hue=output.iloc[:,5], data=output, palette='viridis', s=40, legend="full");
plt.legend(loc='center right', fontsize='10');

# %%
output.to_csv('out.csv', index=False)

# %% [markdown]
# #Strategi pemasaran seperti apa yang terbaik untuk setiap klaster?

# %% [markdown]
# Berdasarkan hasil clustering, terlihat adanya 5 kelompok atau cluster yang berbeda. Setiap
# cluster memiliki karakteristik pendapatan dan pengeluaran yang unik, sehingga memerlukan
# strategi pemasaran yang disesuaikan.
# 1. Cluster 4 merupakan kelompok dengan pendapatan rendah dan pengeluaran rendah.
# Kelompok ini cenderung berhati-hati dalam menggunakan uang. Strategi pemasaran yang
# tepat adalah menawarkan produk atau layanan terjangkau dengan nilai yang baik.
# 2. Cluster 3 memiliki pendapatan menengah ke bawah dan pengeluaran moderat. Kelompok
# ini cukup selektif dalam membelanjakan uang. Strategi pemasaran yang cocok adalah
# menawarkan produk atau layanan dengan kualitas baik dan harga terjangkau.
# 3. Cluster 2 merupakan kelompok dengan pendapatan menengah ke atas dan pengeluaran
# moderat. Kelompok ini cenderung memilih produk atau layanan dengan kualitas baik dan
# harga yang masuk akal. Strategi pemasaran yang tepat adalah menawarkan produk atau
# layanan dengan kualitas tinggi dan menekankan pada nilai yang diberikan.
# 4. Cluster 1 memiliki pendapatan tinggi dan pengeluaran tinggi. Kelompok ini lebih
# cenderung mencari produk atau layanan premium dan ekslusif. Strategi pemasaran yang
# cocok adalah menawarkan produk atau layanan berkualitas tinggi dengan fitur dan layanan
# tambahan.
# 5. Cluster 0 merupakan kelompok dengan pendapatan sangat tinggi dan pengeluaran
# sangat tinggi. Kelompok ini mencari produk atau layanan mewah dan eksklusif. Strategi
# pemasaran yang tepat adalah menawarkan produk atau layanan ultra-premium dengan
# pengalaman yang tak terlupakan. Promosi melalui media khusus atau acara eksklusif juga
# dapat dilakukan.
